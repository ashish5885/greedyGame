# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import re

# %%
data = pd.read_csv('sample_data_set_2 - Sheet1 (1).csv')

# %%
data.head()
# Out:
#           Date                     App                    Ad Group  \
# 0  08 Sep 2020  (SDK X) Cricket Mazza   Cricket Mazza Banner (AdX)
# 1  08 Sep 2020  (SDK X) Cricket Mazza                       320x50
# 2  08 Sep 2020  (SDK X) Cricket Mazza               Dream11_320x50
# 3  08 Sep 2020  (SDK X) Cricket Mazza                  My11_320x50
# 4  06 Sep 2020  (SDK X) Cricket Mazza   Cricket Mazza Banner (AdX)
#
#         State  Revenue  Ad Requests  Ad Responses Fill Rate  Impressions  \
# 0  Unresolved      0.0      3932330       3926253     99.9%      3849749
# 1  Unresolved      0.0      3932330           119     99.9%          118
# 2  Unresolved      0.0      3932330            96     99.9%           93
# 3  Unresolved      0.0      3932330           111     99.9%          110
# 4  Unresolved      0.0      3839002       3834328     99.9%      3785127
#
#   Render Rate  1st Clicks  2nd Clicks
# 0       98.1%       10199           0
# 1       99.2%           2           2
# ...

# %% [markdown]
# ## Q1

# %%
rev = data.groupby('App')[['Revenue','Ad Responses','Ad Requests','Impressions','1st Clicks','2nd Clicks']].sum()

# %%
rev.sort_values(by='Revenue', ascending = False)
# Out:
#                                                  Revenue  Ad Responses  \
# App
# Callbreak Multiplayer                             869.40     131423691
# Bottle Shooting Game                              753.89      17484947
# World Cricket Championship 2                      643.44      15099068
# Traffic Bangalore: Check Fines                    280.33       1728060
# World Cricket Championship  Lt                    145.27       1475191
# ...                                                  ...           ...
# Halloween Cars: Monster Race                        0.00             0
# Halloween Town Racing                               0.00             0
# Hey Flower                                          0.00            56
# Hindi English Translator                            0.00           900
# Zoo Craft : Blocky World Construction & Builder     0.00          2907
#
#                                                  Ad Requests  Impressions  \
# App
# ...

# %% [markdown]
# ## Q4

# %%
data.groupby('Ad Group')[['Revenue']].sum().sort_values(by = 'Revenue')
# Out:
#                                         Revenue
# Ad Group
# test                                       0.00
# Live Talk_Admob_MCM                        0.00
# Latest Attitude Status 2020_Admob          0.00
# Kannada Keyboard_Inmobi                    0.00
# Jesus Wallpapers                           0.00
# ...                                         ...
# Dream11_NonCore                          236.07
# IPL banner                               260.04
# Callbreak Multiplayer2_Inmobi_No Floor   264.99
# MY11Circle_IN_SG_1500                    271.80
# Bottle Shooting Game_Admob_ML            350.40
#
# [188 rows x 1 columns]
